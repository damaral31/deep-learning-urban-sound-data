# %%
from models.CNN import SoundCNN
from trainer import Train
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 from models.CNN import SoundCNN
# ----> 2 from trainer import Train
#
# ModuleNotFoundError: No module named 'trainer'

# %%
FOLDS = [f"fold{i}" for i in range(1, 11)]
DATA_PATH = "datasets"

# %%
model_instance = SoundCNN(num_classes=10, SqueezeExcitation=False, in_channels=5)
trainer = Train(dataset_root_path=DATA_PATH, name="CNN", dataset_type="preprocessing", model=model_instance, num_classes=10, batch_size=64, epochs=50, learning_rate=1e-3, patience=5)
trainer.run(folds=FOLDS)
# Out:
# Training configuration:
#   Device: cuda
#   Model: SoundCNN
#   Parameters: total=103,178, trainable=103,178
#   Num classes: 10
#   Batch size: 64
#   Epochs: 50
#   Learning rate: 0.001
#   Early stopping patience: 5
#   Save directory: c:\Users\diogo\OneDrive\Documents\GitHub\deep-learning-urban-sound-data\results
#
# Starting training with cross-validation...
#
#
# === Train = ['fold3', 'fold4', 'fold5', 'fold6', 'fold7', 'fold8', 'fold9', 'fold10'], Validation = fold2, Test = fold1 ===
#
# --- Epoch 1/50 ---
# ...
# Validating: 100%|██████████| 14/14 [00:01<00:00,  9.07it/s, loss=1.4564, acc=0.5101]
# Train Loss: 1.6918, Train Acc: 0.3921, Val Loss: 1.4564, Val Acc: 0.5101
#
# --- Epoch 2/50 ---
# ...
# Validating: 100%|██████████| 14/14 [00:01<00:00, 12.38it/s, loss=1.0734, acc=0.6565]
# Train Loss: 1.2545, Train Acc: 0.5533, Val Loss: 1.0734, Val Acc: 0.6565
#
# --- Epoch 3/50 ---
# ...
# Validating: 100%|██████████| 14/14 [00:01<00:00, 12.49it/s, loss=1.0315, acc=0.6340]
# ...

# %%
model_instance = SoundCNN(num_classes=10, SqueezeExcitation=True, in_channels=5)
trainer = Train(dataset_root_path=DATA_PATH, name="CNN", dataset_type="preprocessing", model=model_instance, num_classes=10, batch_size=64, epochs=50, learning_rate=1e-3, patience=5)
trainer.run(folds=FOLDS)
