# %% [markdown]
# ## Squeeze-Excitation and Attention-based enhacments on UrbanSound8K's deep learning baseline approch

# %% [markdown]
# ### GUIAO (A REMOVER)
#
# ##### TUDO DEVE SER ESCRITO SEGUINDO ESTA ESTRUTURA: CONTEXTO E MOTIVACAO, O QUE FIZEMOS E PORQUE, RESULTADOS, CONCLCUSOES
# ##### NEM TUDO FOI RODADO AQUI. FAZER REFERENCIA AOS FICHEIROS RODADOS DOS QUAIS IMPORTAMOS RESULTADOS
#
#
# 1. ABSTRACT (FAzer no FIM!)
# 2. INTRODUCAO (Aquele texto de chacha mas que fica sempre bem)
# 3. UrbanSound8K (EDA)
# 4. Metodologia<br>
# 4.1. Preprocessamneto<br>
# 4.2. Augmentation<br>
# 4.3. Datasets (Preprocessing singlechannel - baseline, preprocessing multichannel, augmentation com preprocessing singlechannel, augmentation com preprocessing multichanel)<br>
# 4.4. Modelos (Arquiteturas, Versoes previas, porque das mudancas par esta arquitetura)<br>
# 4.5. Configuracao de Teste (Loss, optimizer, early stopping, etc)<br>
# 5. Resultados
# 6. Conclusoes

# %% [markdown]
# ### Arquiteturas

# %% [markdown]
# ![CNN/ACNN/SECNN](img/CNN.png)
# ![RNN](img/RNN.png)
# ![BiRNN](img/BiRNN.png)
# ![LSTM](img/LSTM.png)
