# %%
from models.CNN import SoundCNN
from models.BiRNN import SoundBiRNN
from models.RNN import SoundRNN
from models.LSTM import SoundLSTM
from trainer import Train

# %%
FOLDS = [f"fold{i}" for i in range(1, 11)]
DATA_PATH = "datasets"

# %% [markdown]
# ### PREPROCESSING SINGLE CHANNEL

# %%
model_instance = SoundCNN(num_classes=10, SqueezeExcitation=False, in_channels=1)
trainer = Train(dataset_root_path=DATA_PATH, name="CNN", dataset_type="singlechannel", model=model_instance, num_classes=10, batch_size=64, epochs=50, learning_rate=1e-3, patience=5)
trainer.run(folds=FOLDS)
# Out:
# Training configuration:
#   Device: cuda
#   Model: SoundCNN
#   Parameters: total=102,026, trainable=102,026
#   Num classes: 10
#   Batch size: 64
#   Epochs: 50
#   Learning rate: 0.001
#   Early stopping patience: 5
#   Save directory: c:\Users\diogo\OneDrive\Documents\GitHub\deep-learning-urban-sound-data\results
#   Dataset type: singlechannel
# Loss function: CrossEntropyLoss
# Regularization (L2 weight decay): 0.0001
# Optimizer: Adam
#
#
# Starting training with cross-validation...
#
#
# === Train ['fold3', 'fold4', 'fold5', 'fold6', 'fold7', 'fold8', 'fold9', 'fold10'], Validation = fold2, Test = fold1 ===
#
# --- Epoch 1/50 ---
# ...
# Validating: 100%|██████████| 14/14 [00:00<00:00, 18.28it/s, loss=1.5726, acc=0.3694]
# Train Loss: 1.7174, Train Acc: 0.3796, Val Loss: 1.5726, Val Acc: 0.3694
#
# --- Epoch 2/50 ---
# ...
# Validating: 100%|██████████| 14/14 [00:00<00:00, 14.50it/s, loss=0.9684, acc=0.6700]
# Train Loss: 1.2371, Train Acc: 0.5533, Val Loss: 0.9684, Val Acc: 0.6700
#
# ...

# %%
model_instance = SoundCNN(num_classes=10, AttentionBlock=True, in_channels=1)
trainer = Train(dataset_root_path=DATA_PATH, name="ACNN", dataset_type="singlechannel", model=model_instance, num_classes=10, batch_size=64, epochs=50, learning_rate=1e-3, patience=5)
trainer.run(folds=FOLDS)
# Out:
# Training configuration:
#   Device: cuda
#   Model: SoundCNN
#   Parameters: total=104,074, trainable=104,074
#   Num classes: 10
#   Batch size: 64
#   Epochs: 50
#   Learning rate: 0.001
#   Early stopping patience: 5
#   Save directory: c:\Users\diogo\OneDrive\Documents\GitHub\deep-learning-urban-sound-data\results
#   Dataset type: singlechannel
# Loss function: CrossEntropyLoss
# Regularization (L2 weight decay): 0.0001
# Optimizer: Adam
#
#
# Starting training with cross-validation...
#
#
# === Train ['fold3', 'fold4', 'fold5', 'fold6', 'fold7', 'fold8', 'fold9', 'fold10'], Validation = fold2, Test = fold1 ===
#
# --- Epoch 1/50 ---
# ...
# Validating: 100%|██████████| 14/14 [00:00<00:00, 17.44it/s, loss=1.2043, acc=0.5574]
# Train Loss: 1.6823, Train Acc: 0.3856, Val Loss: 1.2043, Val Acc: 0.5574
#
# --- Epoch 2/50 ---
# ...
# Validating: 100%|██████████| 14/14 [00:00<00:00, 14.02it/s, loss=0.8440, acc=0.7264]
# Train Loss: 1.1703, Train Acc: 0.5774, Val Loss: 0.8440, Val Acc: 0.7264
#
# ...

# %%
model_instance = SoundBiRNN(num_classes=10, in_channels=1)
trainer = Train(dataset_root_path=DATA_PATH, name="BiRNN", dataset_type="singlechannel", model=model_instance, num_classes=10, batch_size=64, epochs=50, learning_rate=1e-3, patience=5)
trainer.run(folds=FOLDS)
# Out:
# Training configuration:
#   Device: cuda
#   Model: SoundBiRNN
#   Parameters: total=431,882, trainable=431,882
#   Num classes: 10
#   Batch size: 64
#   Epochs: 50
#   Learning rate: 0.001
#   Early stopping patience: 5
#   Save directory: c:\Users\diogo\OneDrive\Documents\GitHub\deep-learning-urban-sound-data\results
#   Dataset type: singlechannel
# Loss function: CrossEntropyLoss
# Regularization (L2 weight decay): 0.0001
# Optimizer: Adam
#
#
# Starting training with cross-validation...
#
#
# === Train ['fold3', 'fold4', 'fold5', 'fold6', 'fold7', 'fold8', 'fold9', 'fold10'], Validation = fold2, Test = fold1 ===
#
# --- Epoch 1/50 ---
# ...
# Validating: 100%|██████████| 14/14 [00:00<00:00, 15.75it/s, loss=1.6305, acc=0.4099]
# Train Loss: 1.9975, Train Acc: 0.2614, Val Loss: 1.6305, Val Acc: 0.4099
#
# --- Epoch 2/50 ---
# ...
# Validating: 100%|██████████| 14/14 [00:01<00:00, 10.12it/s, loss=1.4905, acc=0.5248]
# Train Loss: 1.7876, Train Acc: 0.3406, Val Loss: 1.4905, Val Acc: 0.5248
#
# ...

# %%
model_instance = SoundRNN(num_classes=10, in_channels=1)
trainer = Train(dataset_root_path=DATA_PATH, name="RNN", dataset_type="singlechannel", model=model_instance, num_classes=10, batch_size=64, epochs=50, learning_rate=1e-3, patience=5)
trainer.run(folds=FOLDS)
# Out:
# Training configuration:
#   Device: cuda
#   Model: SoundRNN
#   Parameters: total=199,178, trainable=199,178
#   Num classes: 10
#   Batch size: 64
#   Epochs: 50
#   Learning rate: 0.001
#   Early stopping patience: 5
#   Save directory: c:\Users\diogo\OneDrive\Documents\GitHub\deep-learning-urban-sound-data\results
#   Dataset type: singlechannel
# Loss function: CrossEntropyLoss
# Regularization (L2 weight decay): 0.0001
# Optimizer: Adam
#
#
# Starting training with cross-validation...
#
#
# === Train ['fold3', 'fold4', 'fold5', 'fold6', 'fold7', 'fold8', 'fold9', 'fold10'], Validation = fold2, Test = fold1 ===

# %%
model_instance = SoundLSTM(num_classes=10, in_channels=1)
trainer = Train(dataset_root_path=DATA_PATH, name="LSTM", dataset_type="singlechannel", model=model_instance, num_classes=10, batch_size=64, epochs=50, learning_rate=1e-3, patience=5)

# %% [markdown]
# ### PREPROCESSING MULTICHANNEL

# %%
model_instance = SoundCNN(num_classes=10, SqueezeExcitation=False, in_channels=5)
trainer = Train(dataset_root_path=DATA_PATH, name="CNN", dataset_type="preprocessing", model=model_instance, num_classes=10, batch_size=64, epochs=50, learning_rate=1e-3, patience=5)
trainer.run(folds=FOLDS)

# %%
model_instance = SoundCNN(num_classes=10, AttentionBlock=True, in_channels=5)
trainer = Train(dataset_root_path=DATA_PATH, name="ACNN", dataset_type="preprocessing", model=model_instance, num_classes=10, batch_size=64, epochs=50, learning_rate=1e-3, patience=5)
trainer.run(folds=FOLDS)

# %%
model_instance = SoundBiRNN(num_classes=10, in_channels=5)
trainer = Train(dataset_root_path=DATA_PATH, name="BiRNN", dataset_type="preprocessing", model=model_instance, num_classes=10, batch_size=64, epochs=50, learning_rate=1e-3, patience=5)
trainer.run(folds=FOLDS)

# %%
model_instance = SoundRNN(num_classes=10, in_channels=5)
trainer = Train(dataset_root_path=DATA_PATH, name="RNN", dataset_type="preprocessing", model=model_instance, num_classes=10, batch_size=64, epochs=50, learning_rate=1e-3, patience=5)
trainer.run(folds=FOLDS)

# %%
model_instance = SoundLSTM(num_classes=10, in_channels=5)
trainer = Train(dataset_root_path=DATA_PATH, name="LSTM", dataset_type="preprocessing", model=model_instance, num_classes=10, batch_size=64, epochs=50, learning_rate=1e-3, patience=5)
